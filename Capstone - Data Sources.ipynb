# %% [markdown]
# # Analyzing San Diego's Housing Auction Data

# %% [markdown]
# ## Data Sources

# %% [markdown]
# The core analysis done in this report revolves around estimating a winning bid and estimating the potential sale price of a property. To estimate a winning bid for properties in the upcoming auction, we will need the following data:
#
# <ul>
#     <li>Historical Auction Data</li>
#     <li>Upcoming Auction Data</li>
#     <li>Tax Assessor Parcel Data</li>
#     <li>Foursquare Data</li>
#     <li>San Diego Property Sales Data</li>
# </ul>
#
# To estimate the potential sale price of a property after the auction, we will need the following data:
#
# <ul>
#     <li>Tax Assessor Parcel Data</li>
#     <li>Foursquare Data</li>
#     <li>San Diego Property Sales Data</li>
# </ul>
#
# The following sections will go into detail of how each data source will be used for our analysis.

# %% [markdown]
# ### Historical Auction Data

# %% [markdown]
# The San Diego Treasurer-Tax Collector provides data on past auctions. This data contains information on which property went on auction, the opening bid and winning bid, along with other informational variables. Here is a sample of the data:

# %%
import pandas as pd

histauctdata = pd.read_csv('TotalSales.csv')
print(histauctdata.shape)
histauctdata.head()
# Out:
# (5235, 13)
#     ID#         APN                                            Address  \
# 0  0001  1026011300                                       FALLBROOK CA
# 1  0019  1291807500                  REGINA GLN VALLEY CENTER CA 92082
# 2  0020  1292923600    11146 OLD CASTLE RD VALLEY CENTER CA 92082-5605
# 3  0021  1293303400  30642 ROLLING HILLS DR VALLEY CENTER CA 92082-...
# 4  0022  1293902900                 CIRCLE R LN VALLEY CENTER CA 92082
#
#                                 Property Description Tax Rate Area Land Value  \
# 0                      DOC60-56347 IN NEQ SEC 8-9-3W         75022    7010.00
# 1                                              PAR 1         94075  132088.00
# 2                              18.94 AC M/L IN PAR 1         94050  519312.00
# 3  (EX DOCS53418REC70&amp;23787REC72)SWQ OF NEQ S...         94058  660572.00
# 4                                              PAR 4         94025  166252.00
#
#   Improvements Assessed Value Assessed Value Year Sale Date  Opening Bid  \
# 0         0.00        7010.00                2019  3/4/2020       3000.0
# 1         0.00      132088.00                2019  3/4/2020      17500.0
# 2    382992.00      902304.00                2019  3/4/2020     434000.0
# 3     30020.00      690592.00                2019  3/4/2020     332000.0
# 4         0.00      166252.00                2019  3/4/2020      26700.0
#
#    Winning Bid      Notes
# 0      12900.0        NaN
# 1     142100.0        NaN
# 2     950100.0  Forfeited
# 3     400100.0  Forfeited
# 4     115100.0        NaN

# %% [markdown]
# This data will be used (along with other data sources) to model winning bids.

# %% [markdown]
# ### Upcoming Auction Data

# %% [markdown]
# The upcoming auction provides a workbook of propertie that are available for bid. This will be the catalog of potential investment for investors. A smaple of the data is provided below:

# %%
auctiondata = pd.read_excel('3_17_2021_Auction_List_ImprovedProperty_20210215_2040.xls')
print(auctiondata.shape)  
auctiondata.head()
# Out:
# (63, 15)
#    ID#         APN                                   Street Address  \
# 0    5  1023622000  5710 RAINBOW HEIGHTS RD FALLBROOK CA 92028-8844
# 1   22  1211304300  4782 SLEEPING INDIAN RD FALLBROOK CA 92028-8875
# 2   23  1213223100          3816 CAZADOR LN FALLBROOK CA 92028-8880
# 3   27  1233402300        4577 LA CANADA RD FALLBROOK CA 92028-9488
# 4   34  1292110800         10079 W LILAC RD ESCONDIDO CA 92026-5308
#
#    Tax Rate Area  Land Value  Improvements  Total Assessed Value  \
# 0          93011      116469         88498                204967
# 1          75015      124409        348619                473028
# 2          75009      225195        225195                450390
# 3          75013      103536        169812                273348
# 4          94099      169793        318362                488155
#
#    Assessed Value Year                               Property Description  \
# 0                 2020  (EX RD)PAR A PER DOC89-510014 IN SEQ OF SEQ SE...
# 1                 2020                     DOC59-6680 IN SWQ SEC 13-10-4W
# 2                 2020                                              PAR 3
# 3                 2020                                         POR LOT 58
# 4                 2020                                      (EX ST) PAR 3
#
#    Your Max Bid  Opening Bid  Best Bid Status          Close(PDT) Canceled
# 0             0       101000         0     -  2021-03-15 08:00:00      NaN
# 1             0       232000         0     -  2021-03-15 08:00:00      NaN
# 2             0       221000         0     -  2021-03-15 08:00:00      NaN
# 3             0       134000         0     -  2021-03-15 08:00:00      NaN
# 4             0       240000         0     -  2021-03-15 08:00:00      NaN

# %% [markdown]
# ### Tax Assessor Parcel Data

# %% [markdown]
# The auction data alone does not provide enough information to accurately predict the winning bid for a property. It misses key information such as number of bedrooms, number of bathrooms, square footage, etc. These parameters are crucial to understanding what the different features of a property. Thankfully, the county tax assessor provides information on each property parcel in San Diego County. This data source contains all of the information needed to make a tax asseessment. Much of the information in this data source overlaps with our needs. Below is a sample of the data:

# %%
pip install simpledbf
# Out:
# Collecting simpledbf
#   Downloading https://files.pythonhosted.org/packages/8a/d3/e4c25cd8f739dd7ddd19c255cd5552e08cdd439ac51a36ae12640ce8a748/simpledbf-0.2.6.tar.gz
# Building wheels for collected packages: simpledbf
#   Building wheel for simpledbf (setup.py) ... done
#   Stored in directory: /home/jupyterlab/.cache/pip/wheels/72/dd/df/cdfb970a508ef9750ebb4b6e035a3410c3d62b5a6a91d2aafc
# Successfully built simpledbf
# Installing collected packages: simpledbf
# Successfully installed simpledbf-0.2.6
# Note: you may need to restart the kernel to use updated packages.

# %%
from simpledbf import Dbf5

dbf = Dbf5('PARCELS.dbf')
df = dbf.to_dataframe()

print(df.shape) 
print(df.columns)
df.head()
# Out:
# PyTables is not installed. No support for HDF output.
# (1075406, 63)
# Index(['APN', 'APN_8', 'PARCELID', 'OWN_NAME1', 'OWN_NAME2', 'OWN_NAME3',
#        'FRACTINT', 'OWN_ADDR1', 'OWN_ADDR2', 'OWN_ADDR3', 'OWN_ADDR4',
#        'OWN_ZIP', 'SITUS_JURI', 'SITUS_STRE', 'SITUS_SUFF', 'SITUS_POST',
#        'SITUS_PRE_', 'SITUS_ADDR', 'SITUS_FRAC', 'SITUS_BUIL', 'SITUS_SUIT',
#        'LEGLDESC', 'ASR_LAND', 'ASR_IMPR', 'ASR_TOTAL', 'DOCTYPE', 'DOCNMBR',
#        'DOCDATE', 'ACREAGE', 'TAXSTAT', 'OWNEROCC', 'TRANUM', 'ASR_ZONE',
#        'ASR_LANDUS', 'UNITQTY', 'SUBMAP', 'SUBNAME', 'NUCLEUS_ZO',
#        'NUCLEUS_US', 'SITUS_COMM', 'YEAR_EFFEC', 'TOTAL_LVG_', 'BEDROOMS',
#        'BATHS', 'ADDITION_A', 'GARAGE_CON', 'GARAGE_STA', 'CARPORT_ST', 'POOL',
#        'PAR_VIEW', 'USABLE_SQ_', 'QUAL_CLASS', 'NUCLEUS_SI', 'NUCLEUS__1',
#        'NUCLEUS__2', 'SITUS_ZIP', 'x_coord', 'y_coord', 'overlay_ju',
#        'sub_type', 'multi', 'SHAPE_STAr', 'SHAPE_STLe'],
#       dtype='object')
#           APN     APN_8  PARCELID  \
# 0  5911404900  59114049     13233
# 1  4982603900  49826039     13235
# 2  4982604500  49826045     13236
# 3  6782511200  67825112     13238
# 4  4775902300  47759023     13244
#
#                                       OWN_NAME1              OWN_NAME2  \
# 0                   JOCIS LIVING TRUST 05-11-19                    NaN
# 1  SCHAFFROTH EDWARD&GALE FAMILY TRUST 07-05-01                    NaN
# 2                                 REHUREK BARRY                    NaN
# 3                         PROMONTORY ASSOCIATES  PROMONTORY ASSOCIATES
# 4               NGUYEN-LE LIVING TRUST 11-26-19                    NaN
#
#   OWN_NAME3  FRACTINT                    OWN_ADDR1                 OWN_ADDR2  \
# 0       NaN       1.0               3451 MALITO DR                 BONITA CA
# 1       NaN       1.0             1640 CHASE LN #B               EL CAJON CA
# 2       NaN       1.0                 P O BOX 1062               EL CAJON CA
# 3       NaN       4.0  C/O CARLETON MANAGEMENT INC  11440 W BERNARDO CT #390
# 4       NaN       1.0          4857 EBONY RIDGE RD              SAN DIEGO CA
#
#       OWN_ADDR3  ... NUCLEUS__1 NUCLEUS__2   SITUS_ZIP       x_coord  \
# 0           NaN  ...          0        NaN       91902  6.317739e+06
# 1           NaN  ...          0        NaN  92020-8306  6.350493e+06
# 2           NaN  ...          0        NaN  92020-8270  6.350531e+06
# 3  SAN DIEGO CA  ...          0        NaN       92127  6.306441e+06
# 4           NaN  ...          0        NaN       92105  6.304368e+06
#
#         y_coord overlay_ju sub_type  multi     SHAPE_STAr   SHAPE_STLe
# 0  1.823133e+06         CN        1      N    2197.635742   262.298507
# 1  1.860789e+06         CN        1      N   55587.956055   982.044216
# 2  1.861636e+06         CN        1      N   57767.315430   925.790174
# 3  1.952659e+06         SD        1      N  142397.666016  1565.520959
# 4  1.847093e+06         SD        1      N    2768.697266   275.716807
#
# [5 rows x 63 columns]

# %% [markdown]
# This data will be used as features of a property in helping to determine the value of a property. Determining the value of a property will be crucial to estimating a winning bid and a the sale price of a home.

# %% [markdown]
# ### Foursquare Data

# %% [markdown]
# In determining the value of a property, it is also wise to check the surroundings of the property. In real estate, "Location, location, location..." is often touted as one of the most important aspects of a property. Understanding where exactly a property is can change the value of a home drastically. Being in close proximity to schools, shopping, freeways, etc. is one of the most important aspects for people buying a home. The Foursquare data will helps us determine which venues are around a certain property. We can use this data to fill in several features of a property (alongside with the parcel data). Here is a sample of the Foursquare data:

# %%
import requests

CLIENT_ID = 'XXXXXXXXXXXXXXXXXXXXXXXXXXX' # your Foursquare ID
CLIENT_SECRET = 'XXXXXXXXXXXXXXXXXXXXXXXXXXX' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version
LIMIT = 100 # A default Foursquare API limit value

# %%
sd_lat = 32.7157
sd_long= -117.1611
radius = 500

url = 'https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&ll={},{}&v={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, sd_lat, sd_long, VERSION, radius, LIMIT)

results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '60316dc78e5f3a3826402105'},
#  'response': {'suggestedFilters': {'header': 'Tap to show:',
#    'filters': [{'name': 'With specials', 'key': 'specials'},
#     {'name': 'Open now', 'key': 'openNow'}]},
#   'headerLocation': 'Central San Diego',
#   'headerFullLocation': 'Central San Diego, San Diego',
#   'headerLocationGranularity': 'neighborhood',
#   'totalResults': 140,
#   'suggestedBounds': {'ne': {'lat': 32.7202000045, 'lng': -117.15576151471417},
#    'sw': {'lat': 32.711199995499996, 'lng': -117.16643848528584}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '428d2880f964a520ac231fe3',
#        'name': 'House of Blues San Diego',
#        'location': {'address': '1055 5th Ave',
#         'crossStreet': 'btwn Broadway & C St',
#         'lat': 32.716438276543975,
#         'lng': -117.1598248839581,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 32.716438276543975,
#           'lng': -117.1598248839581}],
#         'distance': 144,
#         'postalCode': '92101',
#         'cc': 'US',
#         'neighborhood': 'Central San Diego',
#         'city': 'San Diego',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['1055 5th Ave (btwn Broadway & C St)',
#          'San Diego, CA 92101',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e5931735',
#          'name': 'Music Venue',
#          'pluralName': 'Music Venues',
#          'shortName': 'Music Venue',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1753744',
#         'url': 'https://www.grubhub.com/restaurant/house-of-blues-restaurant--bar-1055-fifth-ave-san-diego/1753744?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1753744',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '39508207'}},
#       'referralId': 'e-0-428d2880f964a520ac231fe3-0'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4a5d5b65f964a52094bd1fe3',
#        'name': 'THE US GRANT, A Luxury Collection Hotel, San Diego',
#        'location': {'address': '326 Broadway',
#         'crossStreet': 'at 3rd Ave',
#         'lat': 32.7162307,
#         'lng': -117.1618383,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 32.7162307,
#           'lng': -117.1618383}],
#         'distance': 90,
#         'postalCode': '92101',
#         'cc': 'US',
#         'city': 'San Diego',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['326 Broadway (at 3rd Ave)',
#          'San Diego, CA 92101',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4a5d5b65f964a52094bd1fe3-1'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ac7c857f964a520bfb920e3',
#        'name': 'The Balboa Theatre',
#        'location': {'address': '868 4th Ave',
#         'crossStreet': 'at E St',
#         'lat': 32.714349409759095,
#         'lng': -117.16112234470165,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 32.714349409759095,
#           'lng': -117.16112234470165}],
#         'distance': 150,
#         'postalCode': '92101',
#         'cc': 'US',
#         'city': 'San Diego',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['868 4th Ave (at E St)',
#          'San Diego, CA 92101',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d137941735',
#          'name': 'Theater',
#          'pluralName': 'Theaters',
#          'shortName': 'Theater',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/performingarts_theater_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ac7c857f964a520bfb920e3-2'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '40e0b100f964a52030021fe3',
#        'name': 'Grant Grill',
#        'location': {'address': '326 Broadway',
#         'crossStreet': 'btwn 3rd & 4th Ave',
#         'lat': 32.71612494879766,
#         'lng': -117.16108440701058,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 32.71612494879766,
#           'lng': -117.16108440701058}],
#         'distance': 47,
#         'postalCode': '92101',
#         'cc': 'US',
#         'city': 'San Diego',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['326 Broadway (btwn 3rd & 4th Ave)',
#          'San Diego, CA 92101',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d14e941735',
#          'name': 'American Restaurant',
#          'pluralName': 'American Restaurants',
#          'shortName': 'American',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-40e0b100f964a52030021fe3-3'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4a3dd4d2f964a520b3a21fe3',
#        'name': 'Vin de Syrah Wine Parlor',
#        'location': {'address': '901 5th Ave',
#         'crossStreet': 'at E St',
#         'lat': 32.71472277464215,
#         'lng': -117.1600401722107,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 32.71472277464215,
#           'lng': -117.1600401722107}],
#         'distance': 147,
#         'postalCode': '92101',
#         'cc': 'US',
#         'city': 'San Diego',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['901 5th Ave (at E St)',
#          'San Diego, CA 92101',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d123941735',
#          'name': 'Wine Bar',
#          'pluralName': 'Wine Bars',
#          'shortName': 'Wine Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/winery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '57483904'}},
#       'referralId': 'e-0-4a3dd4d2f964a520b3a21fe3-4'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '55b1cbfa498ec1a2f1b5e61a',
#        'name': 'Art Hookah Lounge',
#        'location': {'address': '923 6th Ave',
#         'lat': 32.71493466431518,
#         'lng': -117.15927387434832,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 32.71493466431518,
#           'lng': -117.15927387434832}],
#         'distance': 191,
#         'postalCode': '92101',
#         'cc': 'US',
#         'city': 'San Diego',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['923 6th Ave',
#          'San Diego, CA 92101',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d121941735',
#          'name': 'Lounge',
#          'pluralName': 'Lounges',
#          'shortName': 'Lounge',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-55b1cbfa498ec1a2f1b5e61a-5'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c48d7c7b5eec9b6e945efa3',
#        'name': 'The Crab Hut',
#        'location': {'address': '1007 5th Ave Apt 101',
#         'crossStreet': 'at Broadway',
#         'lat': 32.71580165829122,
#         'lng': -117.15987145900726,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 32.71580165829122,
#           'lng': -117.15987145900726}],
#         'distance': 115,
#         'postalCode': '92101',
#         'cc': 'US',
#         'city': 'San Diego',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['1007 5th Ave Apt 101 (at Broadway)',
#          'San Diego, CA 92101',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1ce941735',
#          'name': 'Seafood Restaurant',
#          'pluralName': 'Seafood Restaurants',
#          'shortName': 'Seafood',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/seafood_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c48d7c7b5eec9b6e945efa3-6'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4165d880f964a520791d1fe3',
#        'name': 'The Local Eatery and Drinking Hole',
#        'location': {'address': '1065 4th Ave',
#         'crossStreet': 'at C St',
#         'lat': 32.716500985983046,
#         'lng': -117.16093289502611,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 32.716500985983046,
#           'lng': -117.16093289502611}],
#         'distance': 90,
#         'postalCode': '92101',
#         'cc': 'US',
#         'city': 'San Diego',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['1065 4th Ave (at C St)',
#          'San Diego, CA 92101',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d116941735',
#          'name': 'Bar',
#          'pluralName': 'Bars',
#          'shortName': 'Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1084868',
#         'url': 'https://www.grubhub.com/restaurant/the-local-eatery--drinking-hole-1065-4th-ave-san-diego/1084868?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1084868',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '36656939'}},
#       'referralId': 'e-0-4165d880f964a520791d1fe3-7'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b933ab9f964a5204d3c34e3',
#        'name': 'Rei Do Gado',
#        'location': {'address': '939 4th Ave',
#         'crossStreet': 'at Broadway',
#         'lat': 32.715202,
#         'lng': -117.16094,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 32.715202,
#           'lng': -117.16094},
#          {'label': 'entrance', 'lat': 32.71537, 'lng': -117.160936}],
#         'distance': 57,
#         'postalCode': '92101',
#         'cc': 'US',
#         'city': 'San Diego',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['939 4th Ave (at Broadway)',
#          'San Diego, CA 92101',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d16b941735',
#          'name': 'Brazilian Restaurant',
#          'pluralName': 'Brazilian Restaurants',
#          'shortName': 'Brazilian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/argentinian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1967685',
#         'url': 'https://www.grubhub.com/restaurant/rei-do-gado-939-fourth-ave-san-diego/1967685?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1967685',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '178210371'}},
#       'referralId': 'e-0-4b933ab9f964a5204d3c34e3-8'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b7e456cf964a520e2e72fe3',
#        'name': 'Courtyard by Marriott San Diego Downtown',
#        'location': {'address': '530 Broadway St',
#         'lat': 32.7158738,
#         'lng': -117.1594012,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 32.7158738,
#           'lng': -117.1594012}],
#         'distance': 160,
#         'postalCode': '92101',
#         'cc': 'US',
#         'city': 'San Diego',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['530 Broadway St',
#          'San Diego, CA 92101',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '73668032'}},
#       'referralId': 'e-0-4b7e456cf964a520e2e72fe3-9'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '586c1cd68cfe5450f8852f54',
#        'name': 'Trailer Park After Dark',
#        'location': {'address': '835 5th Ave # Ll',
#         'lat': 32.714195246933535,
#         'lng': -117.16007568989619,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 32.714195246933535,
#           'lng': -117.16007568989619}],
#         'distance': 193,
#         'postalCode': '92101',
#         'cc': 'US',
#         'city': 'San Diego',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['835 5th Ave # Ll',
#          'San Diego, CA 92101',
#          'United States']},
#        'categories': [{'id': '56aa371be4b08b9a8d573538',
#          'name': 'Theme Restaurant',
#          'pluralName': 'Theme Restaurants',
#          'shortName': 'Theme Restaurant',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-586c1cd68cfe5450f8852f54-10'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4abd87d6f964a520dc8a20e3',
#        'name': 'Operacaffe',
#        'location': {'address': '835 4th Avenue',
#         'crossStreet': 'btwn E & F St',
#         'lat': 32.71404129343222,
#         'lng': -117.16099578219614,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 32.71404129343222,
#           'lng': -117.16099578219614}],
#         'distance': 184,
#         'postalCode': '92101',
#         'cc': 'US',
#         'city': 'San Diego',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['835 4th Avenue (btwn E & F St)',
#          'San Diego, CA 92101',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '44644354'}},
#       'referralId': 'e-0-4abd87d6f964a520dc8a20e3-11'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4a7bc2a0f964a520c2eb1fe3',
#        'name': 'San Diego Civic Theatre',
#        'location': {'address': '1100 3rd Ave',
#         'crossStreet': 'at B St',
#         'lat': 32.7174219599808,
#         'lng': -117.16231763362885,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 32.7174219599808,
#           'lng': -117.16231763362885}],
#         'distance': 223,
#         'postalCode': '92101',
#         'cc': 'US',
#         'neighborhood': 'Central San Diego',
#         'city': 'San Diego',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['1100 3rd Ave (at B St)',
#          'San Diego, CA 92101',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d137941735',
#          'name': 'Theater',
#          'pluralName': 'Theaters',
#          'shortName': 'Theater',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/performingarts_theater_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4a7bc2a0f964a520c2eb1fe3-12'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b6b9586f964a52034112ce3',
#        'name': 'Best Damn Beer Shop',
#        'location': {'address': '1036 7th Ave',
#         'crossStreet': 'btwn C & Broadway',
#         'lat': 32.716162,
#         'lng': -117.158653,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 32.716162,
#           'lng': -117.158653}],
#         'distance': 234,
#         'postalCode': '92101',
#         'cc': 'US',
#         'neighborhood': 'Central San Diego',
#         'city': 'San Diego',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['1036 7th Ave (btwn C & Broadway)',
#          'San Diego, CA 92101',
#          'United States']},
#        'categories': [{'id': '5370f356bcbc57f1066c94c2',
#          'name': 'Beer Store',
#          'pluralName': 'Beer Stores',
#          'shortName': 'Beer Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/beergarden_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b6b9586f964a52034112ce3-13'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bf8834db182c9b636ad775a',
#        'name': 'Osetra the Fishhouse',
#        'location': {'address': '904 5th Ave',
#         'crossStreet': 'at E St',
#         'lat': 32.71477710693484,
#         'lng': -117.16031402349472,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 32.71477710693484,
#           'lng': -117.16031402349472},
#          {'label': 'entrance', 'lat': 32.714907, 'lng': -117.160296}],
#         'distance': 126,
#         'postalCode': '92101',
#         'cc': 'US',
#         'city': 'San Diego',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['904 5th Ave (at E St)',
#          'San Diego, CA 92101',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1ce941735',
#          'name': 'Seafood Restaurant',
#          'pluralName': 'Seafood Restaurants',
#          'shortName': 'Seafood',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/seafood_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '2189297',
#         'url': 'https://www.grubhub.com/restaurant/osetra-seafood--steaks-904-fifth-ave-san-diego/2189297?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2189297',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '37016446'}},
#       'referralId': 'e-0-4bf8834db182c9b636ad775a-14'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '54dcf93e498e72ab49cd0ba8',
#        'name': 'WestBean Coffee Roasters',
#        'location': {'address': '240 Broadway',
#         'lat': 32.7157362988311,
#         'lng': -117.16246012228085,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 32.7157362988311,
#           'lng': -117.16246012228085},
#          {'label': 'entrance', 'lat': 32.715902, 'lng': -117.162427}],
#         'distance': 127,
#         'postalCode': '92101',
#         'cc': 'US',
#         'city': 'San Diego',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['240 Broadway',
#          'San Diego, CA 92101',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-54dcf93e498e72ab49cd0ba8-15'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '56d21114cd100741b5439b3d',
#        'name': 'Resident Brewing',
#        'location': {'address': '1065 4th Ave',
#         'lat': 32.71651928857628,
#         'lng': -117.16084510087965,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 32.71651928857628,
#           'lng': -117.16084510087965},
#          {'label': 'entrance', 'lat': 32.716576, 'lng': -117.160948}],
#         'distance': 94,
#         'postalCode': '92101',
#         'cc': 'US',
#         'city': 'San Diego',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['1065 4th Ave',
#          'San Diego, CA 92101',
#          'United States']},
#        'categories': [{'id': '50327c8591d4c4b30a586d5d',
#          'name': 'Brewery',
#          'pluralName': 'Breweries',
#          'shortName': 'Brewery',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-56d21114cd100741b5439b3d-16'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '51d0c254498e603aabbc5bae',
#        'name': 'Tender Greens',
#        'location': {'address': '110 W Broadway',
#         'lat': 32.71608221779279,
#         'lng': -117.16392478460716,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 32.71608221779279,
#           'lng': -117.16392478460716},
#          {'label': 'entrance', 'lat': 32.715888, 'lng': -117.164164}],
#         'distance': 267,
#         'postalCode': '92101',
#         'cc': 'US',
#         'city': 'San Diego',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['110 W Broadway',
#          'San Diego, CA 92101',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d157941735',
#          'name': 'New American Restaurant',
#          'pluralName': 'New American Restaurants',
#          'shortName': 'New American',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/newamerican_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '2040668',
#         'url': 'https://www.grubhub.com/restaurant/tender-greens-110-w-broadway-san-diego/2040668?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2040668',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-51d0c254498e603aabbc5bae-17'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bbce75f8a4fb713dc533c9d',
#        'name': "Chef Miguel's Deli",
#        'location': {'address': '1048 7th Ave',
#         'crossStreet': 'at C St',
#         'lat': 32.7165,
#         'lng': -117.15869,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 32.7165,
#           'lng': -117.15869}],
#         'distance': 242,
#         'postalCode': '92101',
#         'cc': 'US',
#         'neighborhood': 'Central San Diego',
#         'city': 'San Diego',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['1048 7th Ave (at C St)',
#          'San Diego, CA 92101',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1c5941735',
#          'name': 'Sandwich Place',
#          'pluralName': 'Sandwich Places',
#          'shortName': 'Sandwiches',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bbce75f8a4fb713dc533c9d-18'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e4c4687bd413c4cc668273f',
#        'name': 'Le Fontainbleau - The Westgate Hotel',
#        'location': {'address': '1055 2nd Ave',
#         'lat': 32.716266999999995,
#         'lng': -117.162452,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 32.716266999999995,
#           'lng': -117.162452}],
#         'distance': 141,
#         'postalCode': '92101',
#         'cc': 'US',
#         'city': 'San Diego',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['1055 2nd Ave',
#          'San Diego, CA 92101',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d10c941735',
#          'name': 'French Restaurant',
#          'pluralName': 'French Restaurants',
#          'shortName': 'French',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/french_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e4c4687bd413c4cc668273f-19'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '40e0b100f964a520db021fe3',
#        'name': 'The Westgate Hotel',
#        'location': {'address': '1055 2nd Ave',
#         'lat': 32.71638,
#         'lng': -117.16247,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 32.71638,
#           'lng': -117.16247}],
#         'distance': 148,
#         'postalCode': '92101',
#         'cc': 'US',
#         'neighborhood': 'Central San Diego',
#         'city': 'San Diego',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['1055 2nd Ave',
#          'San Diego, CA 92101',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '61012338'}},
#       'referralId': 'e-0-40e0b100f964a520db021fe3-20'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5e3df1e09847040008d9797a',
#        'name': 'Mendocino Farms',
#        'location': {'address': '180 Broadway Ste 102',
#         'crossStreet': 'First Ave',
#         'lat': 32.71625,
#         'lng': -117.16336,
#         'labeledLatLngs': [{'label': 'entrance',
#           'lat': 32.716017,
#           'lng': -117.163133},
#          {'label': 'display', 'lat': 32.71625, 'lng': -117.16336}],
#         'distance': 220,
#         'postalCode': '92101',
#         'cc': 'US',
#         'neighborhood': 'Central San Diego',
#         'city': 'San Diego',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['180 Broadway Ste 102 (First Ave)',
#          'San Diego, CA 92101',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1c5941735',
#          'name': 'Sandwich Place',
#          'pluralName': 'Sandwich Places',
#          'shortName': 'Sandwiches',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5e3df1e09847040008d9797a-21'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '502eb1dbe4b08345cc7b2c22',
#        'name': 'Krisp',
#        'location': {'address': '1036 7th Ave',
#         'lat': 32.71621799991383,
#         'lng': -117.15847034271299,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 32.71621799991383,
#           'lng': -117.15847034271299}],
#         'distance': 252,
#         'postalCode': '92101',
#         'cc': 'US',
#         'city': 'San Diego',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['1036 7th Ave',
#          'San Diego, CA 92101',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d186941735',
#          'name': 'Liquor Store',
#          'pluralName': 'Liquor Stores',
#          'shortName': 'Liquor Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_liquor_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '338715',
#         'url': 'https://www.grubhub.com/restaurant/krisp-pizza-1036-7th-ave-san-diego/338715?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=338715',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-502eb1dbe4b08345cc7b2c22-22'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5e35b763fe6a880008b99870',
#        'name': 'Blue Bottle Coffee',
#        'location': {'address': '180 Broadway Ste 101',
#         'lat': 32.715892,
#         'lng': -117.163452,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 32.715892,
#           'lng': -117.163452}],
#         'distance': 221,
#         'postalCode': '92101',
#         'cc': 'US',
#         'neighborhood': 'Central San Diego',
#         'city': 'San Diego',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['180 Broadway Ste 101',
#          'San Diego, CA 92101',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5e35b763fe6a880008b99870-23'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d4319a208d16dcb6a0f7854',
#        'name': 'Cafe 21 Gaslamp',
#        'location': {'address': '802 Fifth Ave',
#         'lat': 32.71372137459579,
#         'lng': -117.16015704024794,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 32.71372137459579,
#           'lng': -117.16015704024794},
#          {'label': 'entrance', 'lat': 32.713797, 'lng': -117.16029}],
#         'distance': 237,
#         'postalCode': '92101',
#         'cc': 'US',
#         'city': 'San Diego',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['802 Fifth Ave',
#          'San Diego, CA 92101',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '2473694',
#         'url': 'https://www.grubhub.com/restaurant/gaslamp-ghost-kitchen-701-fifth-ave-san-diego/2473694?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2473694',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '541939391'}},
#       'referralId': 'e-0-4d4319a208d16dcb6a0f7854-24'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '536b0e2c498eed558fc2200d',
#        'name': 'Döner Mediterranean Grill',
#        'location': {'address': '823 5th Ave',
#         'crossStreet': 'F Street',
#         'lat': 32.71398392992838,
#         'lng': -117.16011943406612,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 32.71398392992838,
#           'lng': -117.16011943406612}],
#         'distance': 211,
#         'postalCode': '92101',
#         'cc': 'US',
#         'city': 'San Diego',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['823 5th Ave (F Street)',
#          'San Diego, CA 92101',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1c0941735',
#          'name': 'Mediterranean Restaurant',
#          'pluralName': 'Mediterranean Restaurants',
#          'shortName': 'Mediterranean',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mediterranean_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '85452147'}},
#       'referralId': 'e-0-536b0e2c498eed558fc2200d-25'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4234d400f964a52010201fe3',
#        'name': 'The Westin San Diego Gaslamp Quarter',
#        'location': {'address': '910 Broadway Cir',
#         'lat': 32.7145814,
#         'lng': -117.1631935,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 32.7145814,
#           'lng': -117.1631935}],
#         'distance': 232,
#         'postalCode': '92101',
#         'cc': 'US',
#         'city': 'San Diego',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['910 Broadway Cir',
#          'San Diego, CA 92101',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4234d400f964a52010201fe3-26'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '52869068498e3289da674749',
#        'name': 'Starbucks',
#        'location': {'address': '75 Horton Plz',
#         'lat': 32.7152149122584,
#         'lng': -117.16133058071135,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 32.7152149122584,
#           'lng': -117.16133058071135}],
#         'distance': 58,
#         'postalCode': '92101',
#         'cc': 'US',
#         'neighborhood': 'Horton Plaza',
#         'city': 'San Diego',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['75 Horton Plz',
#          'San Diego, CA 92101',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-52869068498e3289da674749-27'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d360eebfe972c0f49a99ab3',
#        'name': 'Time Out Sports Tavern',
#        'location': {'address': '634 Broadway',
#         'crossStreet': 'btwn Sixth & Seventh',
#         'lat': 32.71584016527835,
#         'lng': -117.158586401752,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 32.71584016527835,
#           'lng': -117.158586401752}],
#         'distance': 235,
#         'postalCode': '92101',
#         'cc': 'US',
#         'neighborhood': 'Central San Diego',
#         'city': 'San Diego',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['634 Broadway (btwn Sixth & Seventh)',
#          'San Diego, CA 92101',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d14e941735',
#          'name': 'American Restaurant',
#          'pluralName': 'American Restaurants',
#          'shortName': 'American',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '560902',
#         'url': 'https://www.grubhub.com/restaurant/time-out-sports-tavern-634-broadway-san-diego/560902?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=560902',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '33076738'}},
#       'referralId': 'e-0-4d360eebfe972c0f49a99ab3-28'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5393d0e8498e57e15686179c',
#        'name': 'Full Moon Sushi and Kitchen Bar',
#        'location': {'address': '926 5th Ave',
#         'crossStreet': 'btwn Broadway and E Street',
#         'lat': 32.71511660380041,
#         'lng': -117.16026028280073,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 32.71511660380041,
#           'lng': -117.16026028280073},
#          {'label': 'entrance', 'lat': 32.715136, 'lng': -117.160298}],
#         'distance': 101,
#         'postalCode': '92101',
#         'cc': 'US',
#         'city': 'San Diego',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['926 5th Ave (btwn Broadway and E Street)',
#          'San Diego, CA 92101',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1d2941735',
#          'name': 'Sushi Restaurant',
#          'pluralName': 'Sushi Restaurants',
#          'shortName': 'Sushi',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '2328483',
#         'url': 'https://www.grubhub.com/restaurant/full-moon-sushi--kitchen-bar-926-fifth-ave-san-diego/2328483?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2328483',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5393d0e8498e57e15686179c-29'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b9da40ef964a520beb736e3',
#        'name': 'Superfly Tattoo & Body Piercing',
#        'location': {'address': '439 Broadway',
#         'lat': 32.71581068512313,
#         'lng': -117.15983390808105,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 32.71581068512313,
#           'lng': -117.15983390808105}],
#         'distance': 119,
#         'postalCode': '92101',
#         'cc': 'US',
#         'city': 'San Diego',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['439 Broadway',
#          'San Diego, CA 92101',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1de931735',
#          'name': 'Tattoo Parlor',
#          'pluralName': 'Tattoo Parlors',
#          'shortName': 'Tattoo',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/tattoos_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b9da40ef964a520beb736e3-30'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bb7eadd7421a593ef45c140',
#        'name': 'The Melting Pot',
#        'location': {'address': '901 5th Ave',
#         'lat': 32.714844,
#         'lng': -117.15993,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 32.714844,
#           'lng': -117.15993}],
#         'distance': 145,
#         'postalCode': '92101',
#         'cc': 'US',
#         'neighborhood': 'Gaslamp',
#         'city': 'San Diego',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['901 5th Ave',
#          'San Diego, CA 92101',
#          'United States']},
#        'categories': [{'id': '52e81612bcbc57f1066b7a09',
#          'name': 'Fondue Restaurant',
#          'pluralName': 'Fondue Restaurants',
#          'shortName': 'Fondue',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '87944796'}},
#       'referralId': 'e-0-4bb7eadd7421a593ef45c140-31'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '553dd16f498ecddb3119482b',
#        'name': 'Gran Havana Cigar & Hookah Lounge',
#        'location': {'address': '745 4th Ave',
#         'lat': 32.71319532381608,
#         'lng': -117.16104335004216,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 32.71319532381608,
#           'lng': -117.16104335004216}],
#         'distance': 278,
#         'postalCode': '92101',
#         'cc': 'US',
#         'neighborhood': 'Gaslamp',
#         'city': 'San Diego',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['745 4th Ave',
#          'San Diego, CA 92101',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d119941735',
#          'name': 'Hookah Bar',
#          'pluralName': 'Hookah Bars',
#          'shortName': 'Hookah Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/hookahbar_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '2494350',
#         'url': 'https://www.grubhub.com/restaurant/gran-havana-cigar-factory-743-4th-ave-san-diego/2494350?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2494350',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-553dd16f498ecddb3119482b-32'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '568daf60498eaf94b8afbc5d',
#        'name': 'The Taco Stand Downtown',
#        'location': {'address': '645 B St',
#         'crossStreet': '6th Avenue',
#         'lat': 32.7177492877035,
#         'lng': -117.1584974229391,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 32.7177492877035,
#           'lng': -117.1584974229391}],
#         'distance': 333,
#         'postalCode': '92101',
#         'cc': 'US',
#         'city': 'San Diego',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['645 B St (6th Avenue)',
#          'San Diego, CA 92101',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d151941735',
#          'name': 'Taco Place',
#          'pluralName': 'Taco Places',
#          'shortName': 'Tacos',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/taco_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '150837024'}},
#       'referralId': 'e-0-568daf60498eaf94b8afbc5d-33'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '58e6f32ef5957246b9891006',
#        'name': 'Curadero',
#        'location': {'address': '1047 5th Ave',
#         'lat': 32.71619253457952,
#         'lng': -117.15983210796935,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 32.71619253457952,
#           'lng': -117.15983210796935}],
#         'distance': 130,
#         'postalCode': '92101',
#         'cc': 'US',
# ...
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d112941735',
#          'name': 'Juice Bar',
#          'pluralName': 'Juice Bars',
#          'shortName': 'Juice Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/juicebar_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '931984',
#         'url': 'https://www.grubhub.com/restaurant/vitality-tap-650-1st-ave-san-diego/931984?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=931984',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '57523469'}},
#       'referralId': 'e-0-51956237498e5b3fcce3af52-88'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5680b03a498e78a8fe2287dc',
#        'name': 'Tajima Ramen East Village',
#        'location': {'address': '901 E St',
#         'lat': 32.714552634342866,
#         'lng': -117.15639792106415,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 32.714552634342866,
#           'lng': -117.15639792106415},
#          {'label': 'entrance', 'lat': 32.714569, 'lng': -117.156287}],
#         'distance': 458,
#         'postalCode': '92101',
#         'cc': 'US',
#         'city': 'San Diego',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['901 E St',
#          'San Diego, CA 92101',
#          'United States']},
#        'categories': [{'id': '55a59bace4b013909087cb24',
#          'name': 'Ramen Restaurant',
#          'pluralName': 'Ramen Restaurants',
#          'shortName': 'Ramen',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/ramen_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '2039259',
#         'url': 'https://www.grubhub.com/restaurant/tajima-ramen-east-village-901-e-st-san-diego/2039259?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2039259',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5680b03a498e78a8fe2287dc-89'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4a69303bf964a520becb1fe3',
#        'name': 'Whiskey Girl',
#        'location': {'address': '702 5th Ave',
#         'crossStreet': 'at G St',
#         'lat': 32.71271161805056,
#         'lng': -117.16025127032238,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 32.71271161805056,
#           'lng': -117.16025127032238}],
#         'distance': 342,
#         'postalCode': '92101',
#         'cc': 'US',
#         'city': 'San Diego',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['702 5th Ave (at G St)',
#          'San Diego, CA 92101',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d116941735',
#          'name': 'Bar',
#          'pluralName': 'Bars',
#          'shortName': 'Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1160620',
#         'url': 'https://www.grubhub.com/restaurant/whiskey-girl-702-5th-ave-san-diego/1160620?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1160620',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '32886676'}},
#       'referralId': 'e-0-4a69303bf964a520becb1fe3-90'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5a7cc0631953f35cd30ab191',
#        'name': 'Empanada Kitchen',
#        'location': {'address': '819 C St',
#         'lat': 32.716516999999996,
#         'lng': -117.157137,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 32.716516999999996,
#           'lng': -117.157137}],
#         'distance': 382,
#         'postalCode': '92101',
#         'cc': 'US',
#         'city': 'San Diego',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['819 C St',
#          'San Diego, CA 92101',
#          'United States']},
#        'categories': [{'id': '52939a8c3cf9994f4e043a35',
#          'name': 'Empanada Restaurant',
#          'pluralName': 'Empanada Restaurants',
#          'shortName': 'Empanada',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/latinamerican_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '757482',
#         'url': 'https://www.grubhub.com/restaurant/empanada-kitchen-819-c-st-san-diego/757482?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=757482',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5a7cc0631953f35cd30ab191-91'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b706d89f964a520cc192de3',
#        'name': 'Starbucks',
#        'location': {'address': '1194 6th Ave',
#         'lat': 32.71765,
#         'lng': -117.15943,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 32.71765,
#           'lng': -117.15943}],
#         'distance': 267,
#         'postalCode': '92101',
#         'cc': 'US',
#         'city': 'San Diego',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['1194 6th Ave',
#          'San Diego, CA 92101',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b706d89f964a520cc192de3-92'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '59970ecdbfc6d003052f6210',
#        'name': 'Spill The Beans Coffee And Bagel',
#        'location': {'address': '555 Market St',
#         'lat': 32.71151109714702,
#         'lng': -117.15953795715535,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 32.71151109714702,
#           'lng': -117.15953795715535}],
#         'distance': 488,
#         'postalCode': '92101',
#         'cc': 'US',
#         'city': 'San Diego',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['555 Market St',
#          'San Diego, CA 92101',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '2538916',
#         'url': 'https://www.grubhub.com/restaurant/spill-the-beans-555-market-st-san-diego/2538916?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2538916',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-59970ecdbfc6d003052f6210-93'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b9328a6f964a520613834e3',
#        'name': "Salvatore's Cucina Italiana",
#        'location': {'address': '750 Front St',
#         'crossStreet': 'W G St',
#         'lat': 32.712613427484406,
#         'lng': -117.16478557048018,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 32.712613427484406,
#           'lng': -117.16478557048018}],
#         'distance': 487,
#         'postalCode': '92101',
#         'cc': 'US',
#         'city': 'San Diego',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['750 Front St (W G St)',
#          'San Diego, CA 92101',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '83881169'}},
#       'referralId': 'e-0-4b9328a6f964a520613834e3-94'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4adf2888f964a520ea7721e3',
#        'name': 'The Bristol Hotel',
#        'location': {'address': '1055 1st Ave',
#         'crossStreet': 'at C St',
#         'lat': 32.7164218,
#         'lng': -117.1635504,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 32.7164218,
#           'lng': -117.1635504},
#          {'label': 'entrance', 'lat': 32.716356, 'lng': -117.163693}],
#         'distance': 243,
#         'postalCode': '92101',
#         'cc': 'US',
#         'city': 'San Diego',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['1055 1st Ave (at C St)',
#          'San Diego, CA 92101',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '32742164'}},
#       'referralId': 'e-0-4adf2888f964a520ea7721e3-95'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4fa46873e4b09571de68c823',
#        'name': 'The Westin Lobby',
#        'location': {'lat': 32.71491137633529,
#         'lng': -117.16295807077495,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 32.71491137633529,
#           'lng': -117.16295807077495}],
#         'distance': 194,
#         'postalCode': '92101',
#         'cc': 'US',
#         'neighborhood': 'Horton Plaza',
#         'city': 'San Diego',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['San Diego, CA 92101', 'United States']},
#        'categories': [{'id': '4bf58dd8d48988d121941735',
#          'name': 'Lounge',
#          'pluralName': 'Lounges',
#          'shortName': 'Lounge',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4fa46873e4b09571de68c823-96'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4abd4578f964a520578920e3',
#        'name': '5 & A Dime',
#        'location': {'address': '701 8th Ave',
#         'crossStreet': 'at G St',
#         'lat': 32.71260667659825,
#         'lng': -117.15732449734057,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 32.71260667659825,
#           'lng': -117.15732449734057}],
#         'distance': 493,
#         'postalCode': '92101',
#         'cc': 'US',
#         'city': 'San Diego',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['701 8th Ave (at G St)',
#          'San Diego, CA 92101',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d103951735',
#          'name': 'Clothing Store',
#          'pluralName': 'Clothing Stores',
#          'shortName': 'Apparel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4abd4578f964a520578920e3-97'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bd31498462cb7136375dd07',
#        'name': 'Nail Care And Spa',
#        'location': {'address': '8th and F st.',
#         'lat': 32.713516213606674,
#         'lng': -117.15704471445743,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 32.713516213606674,
#           'lng': -117.15704471445743}],
#         'distance': 450,
#         'postalCode': '92101',
#         'cc': 'US',
#         'city': 'San Diego',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['8th and F st.',
#          'San Diego, CA 92101',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d10c951735',
#          'name': 'Cosmetics Shop',
#          'pluralName': 'Cosmetics Shops',
#          'shortName': 'Cosmetics',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/beauty_cosmetic_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bd31498462cb7136375dd07-98'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bf6e0edb182c9b62cad745a',
#        'name': 'Grab & Go Subs',
#        'location': {'address': '109 W C St',
#         'crossStreet': 'at 1st Ave',
#         'lat': 32.716534,
#         'lng': -117.16404,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 32.716534,
#           'lng': -117.16404}],
#         'distance': 290,
#         'postalCode': '92101',
#         'cc': 'US',
#         'neighborhood': 'Central San Diego',
#         'city': 'San Diego',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['109 W C St (at 1st Ave)',
#          'San Diego, CA 92101',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1c5941735',
#          'name': 'Sandwich Place',
#          'pluralName': 'Sandwich Places',
#          'shortName': 'Sandwiches',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bf6e0edb182c9b62cad745a-99'}]}]}}

# %% [markdown]
# The Foursquare features of a property will be used to estimate both a winning bid at auction and the potential sale price of a home.

# %% [markdown]
# ### San Diego Property Sales Data

# %% [markdown]
# The final data source that we will use in this analysis will be San Diego's property sales data. This data will be used to determine the sale price of a property at any given time. Knowing the potential sale price of a home will be a key feature in estimating a winning bid. Note that for the past auction data, we will need to determine the potential sale price of a property at the time of the past auction. For example, if the auction took place in 2017, we will need to determine the property's value as of 2017 to help accurately model what a winning bid would have been. Also, given the upcoming auction, we will use the modeled sales price as a feature in determining the winning bid. Below is an example of the data:

# %%
condosales2020 = pd.read_csv('Condos sold 2020.csv')
print(condosales2020.shape)
condosales2020.head()
# Out:
# (2457, 22)
#                                     Listing Pictures      MLS # Property Type  \
# 0  http://media.crmls.org/mediaz/1DFA0E5F-1302-4B...  200037100   RESIDENTIAL
# 1  http://media.crmls.org/mediaz/F8AB874A-01F2-45...  200002110   RESIDENTIAL
# 2  //cdnparap150.paragonrels.com/ParagonImages/Pr...  200024679   RESIDENTIAL
# 3  http://media.crmls.org/mediaz/3F04B980-0B03-46...  200017840   RESIDENTIAL
# 4  //cdnparap150.paragonrels.com/ParagonImages/Pr...  200008072   RESIDENTIAL
#
#   PropSubT              Address Postal Code City MLS Area  Status      Price  \
# 0    CONDO   2920 Briarwood F12       91902   SD    91902  Closed  $285,000
# 1    CONDO         1234 Neptune       91911   SD    91911  Closed  $399,000
# 2    CONDO  7504 Parkway Dr 208       91942   SD    91942  Closed  $265,000
# 3    CONDO    3514 Fairlomas Rd       91950   SD    91950  Closed  $427,500
# 4    CONDO   1473 Gustavo St. B       92019   SD    92019  Closed  $339,900
#
#    ... LivingArea  DOM  Close Price  Close Date Beds Total Baths Total  \
# 0  ...        599   51    $285,000    12/4/2020          1         1.0
# 1  ...       1374   13    $399,000    2/21/2020          3         2.0
# 2  ...        646    5    $265,000    7/14/2020          1         1.0
# 3  ...       1400   19    $427,500    5/27/2020          2         3.0
# 4  ...       1188   44    $339,900     4/1/2020          2         2.0
#
#    Sold Price Per SQFT  List Price HOA Fee Parking Total
# 0             $475.79    $280,000    $257              1
# 1             $290.39    $399,000      $0              4
# 2             $410.22    $255,000    $272              1
# 3             $305.36    $409,999    $350              2
# 4             $286.11    $339,900    $326              2
#
# [5 rows x 22 columns]

# %% [markdown]
# Furthermore, the sales data will help us create estimates of a property's sales prices to determine if an investment is worth it or not. It is not enough to win a bid, but an investor must also know how much a property can sell for. A rudimentary calculation for determining profit can be:
#
#     Profit = Sale Price - Winning Bid Amount
#
# Ideally, the sales price is large and the winning bid amount is small to maximize profit.
